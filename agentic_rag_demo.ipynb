# %% [raw]
# # Agentic RAG Implementation Demo
#
# This notebook demonstrates the LangGraph Agentic RAG system based on the [official tutorial](https://langchain-ai.github.io/langgraph/tutorials/rag/langgraph_agentic_rag/).
#
# ## What is Agentic RAG?
#
# Agentic RAG is a retrieval-augmented generation system that can:
# - **Decide** whether to retrieve documents or respond directly
# - **Grade** retrieved documents for relevance
# - **Rewrite** questions if documents aren't relevant
# - **Generate** final answers using retrieved context

# %% [raw]
# https://langchain-ai.github.io/langgraph/tutorials/rag/langgraph_agentic_rag/#8-run-the-agentic-rag

# %%
# Install dependencies
import sys

# Install from public PyPI to avoid corporate firewall issues
packages = [
    "langgraph",
    "langchain[openai]", 
    "langchain-community",
    "langchain-text-splitters", 
    "langchain-openai",
    "tiktoken",
    "beautifulsoup4"
]

# Install each package
import subprocess
for package in packages:
    subprocess.run([sys.executable, "-m", "pip", "install", "--index-url", "https://pypi.org/simple/", package])
    
print("✅ All packages installed successfully!")
